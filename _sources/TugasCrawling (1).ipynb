# %% [markdown]
# # Crawling Data (Tugas 1)
#
#
# 1.   DATA TWITTER
# 2.   DATA PTA TRUNOJOYO
# 3.   DATA BERITA ONLINE

# %%
import pandas as pd
#read in the data using pandas
df = pd.read_csv('/content/drive/MyDrive/prosaindata/tugas/Anies Baswedan.csv')
#check data has been read in properly
df.head()
# Out:
#              id        username  \
# 0  1.628410e+18  dbluestarqueen
# 1  1.628410e+18       kayakuwek
# 2  1.628410e+18    alifalhusein
# 3  1.628410e+18      revansian1
# 4  1.628410e+18         a28iwan
#
#                                                tweet
# 0  @ch_chotimah2 @aniesbaswedan Akhirnya pemerint...
# 1  @ale_nyongee @ch_chotimah2 @aniesbaswedan  htt...
# 2  @aniesbaswedan Iya dulu banyak bacot, sekarang...
# 3  @IsoWira @satriohendri @aniesbaswedan Baru kal...
# 4  @yuzinatalia @aniesbaswedan Itu tandanya buzze...
