# %% [markdown]
# <a href="https://colab.research.google.com/github/fadetul-f/prosaindata/blob/main/instalasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# chek posisi direktori saat ini
# %pwd
# Out:
# '/content/drive/My Drive/prosaindata'

# %%
# masuk ke direktori data mining (1)
# %cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
# install jupyter book (2)
# !pip install jupyter-book
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: jsonschema 4.3.3 does not provide the extra 'format-nongpl'
# ...

# %%
# buat forlder tugas
# !jupyter-book create tugas/

# %%
# jupyter build tugas (3)
# !jupyter-book build tugas
# Out:
# Running Jupyter-Book v0.13.2
# Source Folder: /content/drive/My Drive/prosaindata/tugas
# Config Path: /content/drive/My Drive/prosaindata/tugas/_config.yml
# Output Path: /content/drive/My Drive/prosaindata/tugas/_build/html
# Running Sphinx v4.5.0
# [etoc] Changing master_doc to 'intro'
# checking bibtex cache... out of date
# parsing bibtex file /content/drive/My Drive/prosaindata/tugas/references.bib... parsed 5 entries
# myst v0.15.2: MdParserConfig(renderer='sphinx', commonmark_only=False, enable_extensions=['colon_fence', 'dollarmath', 'linkify', 'substitution', 'tasklist'], dmath_allow_labels=True, dmath_allow_space=True, dmath_allow_digits=True, dmath_double_inline=False, update_mathjax=True, mathjax_classes='tex2jax_process|mathjax_process|math|output_area', disable_syntax=[], url_schemes=['mailto', 'http', 'https'], heading_anchors=None, heading_slug_func=None, html_meta=[], footnote_transition=True, substitutions=[], sub_delimiters=['{', '}'], words_per_minute=200)
# ...

# %%
# masuk ke direktori tugas (4)
# %cd /content/drive/MyDrive/prosaindata/tugas
# Out:
# /content/drive/MyDrive/prosaindata/tugas

# %%
# inisialisasi git
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/prosaindata/tugas/.git/

# %%
# menyambungkan google colab ke repository github
# !git remote add origin /https://fadetul-f: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@github.com/fadetul-f/prosaindata.git
# Out:
# fatal: remote origin already exists.

# %%
# install packet ghp-import (5)
# !pip install ghp-import
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# buat web statis dengan paket ghp-import (6)
# !ghp-import -n -p -f _build/html
# Out:
# remote: Permission to fadetul-f/prosaindata.git denied to fadetul-f.
# fatal: unable to access 'https://github.com/fadetul-f/prosaindata.git/': The requested URL returned error: 403
# Traceback (most recent call last):
#   File "/usr/local/bin/ghp-import", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/ghp_import.py", line 300, in main
#     ghp_import(args.pop("directory"), **args)
#   File "/usr/local/lib/python3.8/dist-packages/ghp_import.py", line 283, in ghp_import
#     git.check_call('push', opts['remote'], opts['branch'], '--force')
#   File "/usr/local/lib/python3.8/dist-packages/ghp_import.py", line 119, in check_call
#     sp.check_call(['git'] + list(args), **kwargs)
#   File "/usr/lib/python3.8/subprocess.py", line 364, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command '['git', 'push', 'origin', 'gh-pages', '--force']' returned non-zero exit status 128.
